# %%
# Import the dependencies.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from citipy import citipy
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
 #Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
 city_url = url + "&q=" + city.replace(" ","+")
 print (city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?APPID=96ad2a0fd5a00e2a39c28069f7851d47&q=marawi

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Run an API request for each of the cities.
#try:
# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

   
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1


    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_desc = city_weather["weather"]
        city_current_desc = weather_desc[0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Current Description": city_current_desc
                            })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass



# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Record 31 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 7 | rawson
# Processing Record 33 of Set 7 | dunedin
# Processing Record 34 of Set 7 | tazovskiy
# Processing Record 35 of Set 7 | broome
# Processing Record 36 of Set 7 | bani walid
# Processing Record 37 of Set 7 | uray
# Processing Record 38 of Set 7 | pathein
# Processing Record 39 of Set 7 | faanui
# Processing Record 40 of Set 7 | iqaluit
# Processing Record 41 of Set 7 | merauke
# Processing Record 42 of Set 7 | san isidro
# Processing Record 43 of Set 7 | nioro
# Processing Record 44 of Set 7 | daxian
# City not found. Skipping...
# Processing Record 45 of Set 7 | beaufort
# Processing Record 46 of Set 7 | sabang
# Processing Record 47 of Set 7 | bonavista
# Processing Record 48 of Set 7 | balatonkenese
# Processing Record 49 of Set 7 | lancaster
# Processing Record 50 of Set 7 | santa catarina de tepehuanes
# Processing Record 1 of Set 8 | carira
# Processing Record 2 of Set 8 | burnie
# Processing Record 3 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 4 of Set 8 | karratha
# Processing Record 5 of Set 8 | berdigestyakh
# Processing Record 6 of Set 8 | carnarvon
# Processing Record 7 of Set 8 | sambava
# Processing Record 8 of Set 8 | safranbolu
# Processing Record 9 of Set 8 | port-cartier
# Processing Record 10 of Set 8 | rocha
# Processing Record 11 of Set 8 | akyab
# Processing Record 12 of Set 8 | tinyahuarco
# Processing Record 13 of Set 8 | pisco
# Processing Record 14 of Set 8 | grants pass
# Processing Record 15 of Set 8 | manokwari
# Processing Record 16 of Set 8 | lasa
# Processing Record 17 of Set 8 | alice springs
# Processing Record 18 of Set 8 | kumluca
# Processing Record 19 of Set 8 | geraldton
# Processing Record 20 of Set 8 | san juan
# Processing Record 21 of Set 8 | maniitsoq
# Processing Record 22 of Set 8 | panagar
# Processing Record 23 of Set 8 | nabari
# Processing Record 24 of Set 8 | vardo
# Processing Record 25 of Set 8 | padang
# Processing Record 26 of Set 8 | serenje
# Processing Record 27 of Set 8 | thaba nchu
# Processing Record 28 of Set 8 | meadow lake
# Processing Record 29 of Set 8 | salalah
# Processing Record 30 of Set 8 | te anau
# Processing Record 31 of Set 8 | nelson bay
# Processing Record 32 of Set 8 | luau
# Processing Record 33 of Set 8 | umba
# Processing Record 34 of Set 8 | tumaco
# Processing Record 35 of Set 8 | guanica
# Processing Record 36 of Set 8 | verkhnyaya inta
# Processing Record 37 of Set 8 | zhanaozen
# Processing Record 38 of Set 8 | saint-francois
# Processing Record 39 of Set 8 | ulladulla
# Processing Record 40 of Set 8 | polson
# Processing Record 41 of Set 8 | beringovskiy
# Processing Record 42 of Set 8 | bengkulu
# Processing Record 43 of Set 8 | shaartuz
# City not found. Skipping...
# Processing Record 44 of Set 8 | fallon
# Processing Record 45 of Set 8 | birjand
# Processing Record 46 of Set 8 | tiznit
# Processing Record 47 of Set 8 | dauriya
# Processing Record 48 of Set 8 | shelburne
# Processing Record 49 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 8 | yabrud
# Processing Record 1 of Set 9 | hudson bay
# Processing Record 2 of Set 9 | ketchikan
# Processing Record 3 of Set 9 | laborie
# Processing Record 4 of Set 9 | polis
# Processing Record 5 of Set 9 | pouso alegre
# Processing Record 6 of Set 9 | veraval
# Processing Record 7 of Set 9 | saint-augustin
# Processing Record 8 of Set 9 | tautira
# Processing Record 9 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 9 | walvis bay
# Processing Record 11 of Set 9 | san quintin
# Processing Record 12 of Set 9 | staryy saltiv
# Processing Record 13 of Set 9 | nagato
# Processing Record 14 of Set 9 | barahona
# Processing Record 15 of Set 9 | norrtalje
# Processing Record 16 of Set 9 | beyneu
# Processing Record 17 of Set 9 | togur
# Processing Record 18 of Set 9 | klaksvik
# Processing Record 19 of Set 9 | muroto
# Processing Record 20 of Set 9 | lata
# Processing Record 21 of Set 9 | bathsheba
# Processing Record 22 of Set 9 | cuyo
# Processing Record 23 of Set 9 | lingyuan
# Processing Record 24 of Set 9 | ust-nera
# Processing Record 25 of Set 9 | kaspiysk
# Processing Record 26 of Set 9 | namie
# Processing Record 27 of Set 9 | kapiri mposhi
# Processing Record 28 of Set 9 | vilyuysk
# Processing Record 29 of Set 9 | tari
# Processing Record 30 of Set 9 | nata
# Processing Record 31 of Set 9 | mehamn
# Processing Record 32 of Set 9 | funadhoo
# Processing Record 33 of Set 9 | biak
# Processing Record 34 of Set 9 | cloquet
# Processing Record 35 of Set 9 | bubaque
# Processing Record 36 of Set 9 | namatanai
# Processing Record 37 of Set 9 | smithers
# Processing Record 38 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 39 of Set 9 | beloha
# Processing Record 40 of Set 9 | hurricane
# Processing Record 41 of Set 9 | talara
# Processing Record 42 of Set 9 | lagoa
# Processing Record 43 of Set 9 | sur
# Processing Record 44 of Set 9 | sept-iles
# Processing Record 45 of Set 9 | airai
# Processing Record 46 of Set 9 | husavik
# Processing Record 47 of Set 9 | rumoi
# Processing Record 48 of Set 9 | machachi
# Processing Record 49 of Set 9 | kavieng
# Processing Record 50 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 10 | luganville
# Processing Record 2 of Set 10 | gagnoa
# Processing Record 3 of Set 10 | hailar
# Processing Record 4 of Set 10 | praia da vitoria
# Processing Record 5 of Set 10 | bukachacha
# Processing Record 6 of Set 10 | yugorsk
# Processing Record 7 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 8 of Set 10 | korla
# Processing Record 9 of Set 10 | mumford
# Processing Record 10 of Set 10 | qabis
# City not found. Skipping...
# Processing Record 11 of Set 10 | whitehorse
# Processing Record 12 of Set 10 | lahat
# Processing Record 13 of Set 10 | charyshskoye
# Processing Record 14 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 10 | chemax
# Processing Record 16 of Set 10 | saint-leu
# Processing Record 17 of Set 10 | tete
# Processing Record 18 of Set 10 | kamina
# Processing Record 19 of Set 10 | tres arroyos
# Processing Record 20 of Set 10 | sampit
# Processing Record 21 of Set 10 | namibe
# Processing Record 22 of Set 10 | nalut
# Processing Record 23 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 10 | srednekolymsk
# Processing Record 25 of Set 10 | todos santos
# Processing Record 26 of Set 10 | inta
# Processing Record 27 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 10 | xuchang
# Processing Record 29 of Set 10 | lake havasu city
# Processing Record 30 of Set 10 | ambulu
# Processing Record 31 of Set 10 | serov
# Processing Record 32 of Set 10 | staryy nadym
# Processing Record 33 of Set 10 | necochea
# Processing Record 34 of Set 10 | touros
# Processing Record 35 of Set 10 | piacabucu
# Processing Record 36 of Set 10 | novo aripuana
# Processing Record 37 of Set 10 | santa cruz
# Processing Record 38 of Set 10 | port hedland
# Processing Record 39 of Set 10 | taperoa
# Processing Record 40 of Set 10 | nara
# Processing Record 41 of Set 10 | luwingu
# Processing Record 42 of Set 10 | cabedelo
# Processing Record 43 of Set 10 | iki-burul
# Processing Record 44 of Set 10 | obihiro
# Processing Record 45 of Set 10 | leo
# Processing Record 46 of Set 10 | hirado
# Processing Record 47 of Set 10 | krasnyy chikoy
# Processing Record 48 of Set 10 | gambela
# Processing Record 49 of Set 10 | port hardy
# Processing Record 50 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 11 | oudtshoorn
# Processing Record 2 of Set 11 | jardim
# Processing Record 3 of Set 11 | parczew
# Processing Record 4 of Set 11 | talcahuano
# Processing Record 5 of Set 11 | arman
# Processing Record 6 of Set 11 | mumbwa
# Processing Record 7 of Set 11 | nefteyugansk
# Processing Record 8 of Set 11 | vila velha
# Processing Record 9 of Set 11 | laje
# Processing Record 10 of Set 11 | hede
# Processing Record 11 of Set 11 | sao jose da coroa grande
# Processing Record 12 of Set 11 | ixtapa
# Processing Record 13 of Set 11 | khash
# Processing Record 14 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 11 | berlevag
# Processing Record 16 of Set 11 | flin flon
# Processing Record 17 of Set 11 | klyuchi
# Processing Record 18 of Set 11 | port blair
# Processing Record 19 of Set 11 | phuket
# Processing Record 20 of Set 11 | namanyere
# Processing Record 21 of Set 11 | ust-kuyga
# Processing Record 22 of Set 11 | itaituba
# Processing Record 23 of Set 11 | saldanha
# Processing Record 24 of Set 11 | exu
# Processing Record 25 of Set 11 | byron bay
# Processing Record 26 of Set 11 | buraydah
# Processing Record 27 of Set 11 | rabo de peixe
# Processing Record 28 of Set 11 | wamba
# Processing Record 29 of Set 11 | bhimavaram
# Processing Record 30 of Set 11 | bridlington
# Processing Record 31 of Set 11 | presidencia roque saenz pena
# Processing Record 32 of Set 11 | panguma
# Processing Record 33 of Set 11 | saint-joseph
# Processing Record 34 of Set 11 | quatre cocos
# Processing Record 35 of Set 11 | cravo norte
# Processing Record 36 of Set 11 | birobidzhan
# Processing Record 37 of Set 11 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 38 of Set 11 | hambantota
# Processing Record 39 of Set 11 | yelanskiy
# Processing Record 40 of Set 11 | sadovoye
# Processing Record 41 of Set 11 | chifeng
# Processing Record 42 of Set 11 | qinhuangdao
# Processing Record 43 of Set 11 | havre-saint-pierre
# Processing Record 44 of Set 11 | mogok
# Processing Record 45 of Set 11 | taoudenni
# Processing Record 46 of Set 11 | fairbanks
# Processing Record 47 of Set 11 | brigantine
# Processing Record 48 of Set 11 | pishin
# Processing Record 49 of Set 11 | karatu
# Processing Record 50 of Set 11 | belmonte
# Processing Record 1 of Set 12 | muros
# Processing Record 2 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 3 of Set 12 | coari
# Processing Record 4 of Set 12 | sayan
# Processing Record 5 of Set 12 | oeiras do para
# Processing Record 6 of Set 12 | bilma
# Processing Record 7 of Set 12 | wanaka
# Processing Record 8 of Set 12 | vzmorye
# Processing Record 9 of Set 12 | sulphur
# Processing Record 10 of Set 12 | skjervoy
# Processing Record 11 of Set 12 | wladyslawowo
# Processing Record 12 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 12 | kajaani
# Processing Record 14 of Set 12 | lazaro cardenas
# Processing Record 15 of Set 12 | nyurba
# Processing Record 16 of Set 12 | ghanzi
# Processing Record 17 of Set 12 | kaeo
# Processing Record 18 of Set 12 | shabo
# Processing Record 19 of Set 12 | trincomalee
# Processing Record 20 of Set 12 | marsa matruh
# Processing Record 21 of Set 12 | kampong chhnang
# Processing Record 22 of Set 12 | esmeraldas
# Processing Record 23 of Set 12 | tabou
# Processing Record 24 of Set 12 | penzance
# Processing Record 25 of Set 12 | nova borova
# Processing Record 26 of Set 12 | mugur-aksy
# Processing Record 27 of Set 12 | yangambi
# Processing Record 28 of Set 12 | zhigansk
# Processing Record 29 of Set 12 | kuah
# Processing Record 30 of Set 12 | san policarpo
# Processing Record 31 of Set 12 | araouane
# Processing Record 32 of Set 12 | cap malheureux
# Processing Record 33 of Set 12 | ostrovnoy
# Processing Record 34 of Set 12 | adrar
# Processing Record 35 of Set 12 | chapais
# Processing Record 36 of Set 12 | labuhan
# Processing Record 37 of Set 12 | belaya gora
# Processing Record 38 of Set 12 | tanda
# Processing Record 39 of Set 12 | kenai
# Processing Record 40 of Set 12 | rorvik
# Processing Record 41 of Set 12 | lewistown
# Processing Record 42 of Set 12 | kudahuvadhoo
# Processing Record 43 of Set 12 | lenine
# Processing Record 44 of Set 12 | bordighera
# Processing Record 45 of Set 12 | manono
# Processing Record 46 of Set 12 | borovoy
# Processing Record 47 of Set 12 | moratuwa
# Processing Record 48 of Set 12 | toktogul
# Processing Record 49 of Set 12 | muli
# Processing Record 50 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 1 of Set 13 | omboue
# Processing Record 2 of Set 13 | mackenzie
# Processing Record 3 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 13 | rassvet
# Processing Record 5 of Set 13 | aleppo
# Processing Record 6 of Set 13 | gibato
# Processing Record 7 of Set 13 | puerto escondido
# Processing Record 8 of Set 13 | suihua
# Processing Record 9 of Set 13 | waddan
# Processing Record 10 of Set 13 | ust-maya
# Processing Record 11 of Set 13 | sao gabriel da cachoeira
# Processing Record 12 of Set 13 | kingisepp
# Processing Record 13 of Set 13 | ambilobe
# Processing Record 14 of Set 13 | peniche
# Processing Record 15 of Set 13 | emba
# Processing Record 16 of Set 13 | the valley
# Processing Record 17 of Set 13 | nevelsk
# Processing Record 18 of Set 13 | xam nua
# Processing Record 19 of Set 13 | iwaki
# Processing Record 20 of Set 13 | xichang
# Processing Record 21 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 13 | victoria point
# Processing Record 23 of Set 13 | yulara
# Processing Record 24 of Set 13 | evensk
# Processing Record 25 of Set 13 | bantva
# Processing Record 26 of Set 13 | mmabatho
# Processing Record 27 of Set 13 | oistins
# Processing Record 28 of Set 13 | karpathos
# Processing Record 29 of Set 13 | trinidad
# Processing Record 30 of Set 13 | visby
# Processing Record 31 of Set 13 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 32 of Set 13 | falun
# Processing Record 33 of Set 13 | dalen
# Processing Record 34 of Set 13 | masvingo
# Processing Record 35 of Set 13 | torbay
# Processing Record 36 of Set 13 | kiunga
# Processing Record 37 of Set 13 | kondoa
# Processing Record 38 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 13 | kochevo
# Processing Record 40 of Set 13 | uberaba
# Processing Record 41 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 13 | northam
# Processing Record 43 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 13 | keuruu
# Processing Record 45 of Set 13 | nowy targ
# Processing Record 46 of Set 13 | poum
# Processing Record 47 of Set 13 | asfi
# Processing Record 48 of Set 13 | san cristobal
# Processing Record 49 of Set 13 | arvika
# Processing Record 50 of Set 13 | fare
# Processing Record 1 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 14 | santa fe
# Processing Record 3 of Set 14 | regina
# Processing Record 4 of Set 14 | drjanovo
# City not found. Skipping...
# Processing Record 5 of Set 14 | carauari
# Processing Record 6 of Set 14 | aras
# Processing Record 7 of Set 14 | kasongo-lunda
# Processing Record 8 of Set 14 | nizhniy kuranakh
# Processing Record 9 of Set 14 | usak
# Processing Record 10 of Set 14 | tavda
# Processing Record 11 of Set 14 | moron
# Processing Record 12 of Set 14 | makat
# Processing Record 13 of Set 14 | cartagena
# Processing Record 14 of Set 14 | alto longa
# Processing Record 15 of Set 14 | atar
# Processing Record 16 of Set 14 | sibu
# Processing Record 17 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 18 of Set 14 | hirara
# Processing Record 19 of Set 14 | viedma
# Processing Record 20 of Set 14 | caravelas
# Processing Record 21 of Set 14 | katobu
# Processing Record 22 of Set 14 | tiarei
# Processing Record 23 of Set 14 | ancud
# Processing Record 24 of Set 14 | sakyla
# Processing Record 25 of Set 14 | rush
# Processing Record 26 of Set 14 | karpogory
# Processing Record 27 of Set 14 | shenzhen
# Processing Record 28 of Set 14 | springbok
# Processing Record 29 of Set 14 | tilichiki
# Processing Record 30 of Set 14 | stykkisholmur
# Processing Record 31 of Set 14 | ahuimanu
# Processing Record 32 of Set 14 | rafai
# Processing Record 33 of Set 14 | la asuncion
# Processing Record 34 of Set 14 | strezhevoy
# Processing Record 35 of Set 14 | matinhos
# Processing Record 36 of Set 14 | kodinsk
# Processing Record 37 of Set 14 | aksarayskiy
# Processing Record 38 of Set 14 | gigmoto
# Processing Record 39 of Set 14 | datong
# Processing Record 40 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 41 of Set 14 | kirakira
# Processing Record 42 of Set 14 | vila
# Processing Record 43 of Set 14 | mitsamiouli
# Processing Record 44 of Set 14 | pudozh
# Processing Record 45 of Set 14 | marzuq
# Processing Record 46 of Set 14 | pimentel
# Processing Record 47 of Set 14 | sioux lookout
# Processing Record 48 of Set 14 | mezen
# Processing Record 49 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 15 | chebsara
# Processing Record 2 of Set 15 | yunhe
# Processing Record 3 of Set 15 | vanavara
# Processing Record 4 of Set 15 | klyuchevskiy
# Processing Record 5 of Set 15 | port moresby
# Processing Record 6 of Set 15 | sangar
# Processing Record 7 of Set 15 | guiratinga
# Processing Record 8 of Set 15 | illapel
# Processing Record 9 of Set 15 | chita
# Processing Record 10 of Set 15 | darab
# Processing Record 11 of Set 15 | mount isa
# Processing Record 12 of Set 15 | flinders
# Processing Record 13 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 15 | parrita
# Processing Record 16 of Set 15 | mecca
# Processing Record 17 of Set 15 | cham
# Processing Record 18 of Set 15 | urucara
# Processing Record 19 of Set 15 | harper
# Processing Record 20 of Set 15 | abu dhabi
# Processing Record 21 of Set 15 | moranbah
# Processing Record 22 of Set 15 | kurilsk
# Processing Record 23 of Set 15 | witu
# Processing Record 24 of Set 15 | zhuhai
# Processing Record 25 of Set 15 | peredovaya
# Processing Record 26 of Set 15 | bayan
# Processing Record 27 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 15 | ibotirama
# Processing Record 29 of Set 15 | indiana
# Processing Record 30 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 15 | nabire
# Processing Record 32 of Set 15 | praia
# Processing Record 33 of Set 15 | mayo
# Processing Record 34 of Set 15 | wexford
# Processing Record 35 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 36 of Set 15 | bjornevatn
# Processing Record 37 of Set 15 | guinayangan
# Processing Record 38 of Set 15 | ibra
# Processing Record 39 of Set 15 | tabuk
# Processing Record 40 of Set 15 | owensboro
# Processing Record 41 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 15 | sakakah
# Processing Record 43 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 15 | sao miguel do araguaia
# Processing Record 45 of Set 15 | deputatskiy
# Processing Record 46 of Set 15 | mazurivka
# Processing Record 47 of Set 15 | caloundra
# Processing Record 48 of Set 15 | san joaquin
# Processing Record 49 of Set 15 | dehui
# Processing Record 50 of Set 15 | vestmannaeyjar
# Processing Record 1 of Set 16 | shu
# Processing Record 2 of Set 16 | quelimane
# Processing Record 3 of Set 16 | den helder
# Processing Record 4 of Set 16 | monrovia
# Processing Record 5 of Set 16 | ardakan
# Processing Record 6 of Set 16 | nyazepetrovsk
# Processing Record 7 of Set 16 | moroni
# Processing Record 8 of Set 16 | brookings
# Processing Record 9 of Set 16 | amapa
# Processing Record 10 of Set 16 | novikovo
# Processing Record 11 of Set 16 | havoysund
# Processing Record 12 of Set 16 | lowestoft
# Processing Record 13 of Set 16 | broken hill
# Processing Record 14 of Set 16 | gondanglegi
# Processing Record 15 of Set 16 | warwick
# Processing Record 16 of Set 16 | balkhash
# Processing Record 17 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 16 | santiago del estero
# Processing Record 19 of Set 16 | polovinnoye
# Processing Record 20 of Set 16 | mao
# Processing Record 21 of Set 16 | batemans bay
# Processing Record 22 of Set 16 | bengkalis
# City not found. Skipping...
# Processing Record 23 of Set 16 | bam
# Processing Record 24 of Set 16 | lilongwe
# Processing Record 25 of Set 16 | cirpan
# City not found. Skipping...
# Processing Record 26 of Set 16 | ambon
# Processing Record 27 of Set 16 | nouadhibou
# Processing Record 28 of Set 16 | chicama
# Processing Record 29 of Set 16 | port hawkesbury
# Processing Record 30 of Set 16 | soyo
# Processing Record 31 of Set 16 | kavaratti
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Hilo  19.7297 -155.0900    299.15        47          40
# 1    Haines Junction  60.7522 -137.5108    247.15        70          73
# 2          Hay River  60.8156 -115.7999    238.15        61          10
# 3           Souillac -20.5167   57.5167    298.15        83          40
# 4           Coos Bay  43.3665 -124.2179    283.15        81          90
# ..               ...      ...       ...       ...       ...         ...
# 708       Nouadhibou  20.9310  -17.0347    289.15        72           0
# 709          Chicama  -7.8447  -79.1469    296.36        66         100
# 710  Port Hawkesbury  45.6169  -61.3485    274.15        69          90
# 711             Soyo  -6.1349   12.3689    299.63        85         100
# 712        Kavaratti  10.5669   72.6420    300.49        61          43
#
#      Wind Speed Country Current Description
# 0          4.12      US    scattered clouds
# 1          0.51      CA       broken clouds
# 2          2.06      CA           clear sky
# 3          2.06      MU    scattered clouds
# 4          2.06      US     overcast clouds
# ..          ...     ...                 ...
# 708        7.72      MR           clear sky
# 709        3.58      PE     overcast clouds
# 710        7.20      CA     overcast clouds
# 711        3.70      AO     overcast clouds
# 712        4.52      IN    scattered clouds
#
# [713 rows x 9 columns]

# %%
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]
city_data_df[new_column_order]
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Hilo      US  19.7297 -155.0900    299.15        47
# 1    Haines Junction      CA  60.7522 -137.5108    247.15        70
# 2          Hay River      CA  60.8156 -115.7999    238.15        61
# 3           Souillac      MU -20.5167   57.5167    298.15        83
# 4           Coos Bay      US  43.3665 -124.2179    283.15        81
# ..               ...     ...      ...       ...       ...       ...
# 708       Nouadhibou      MR  20.9310  -17.0347    289.15        72
# 709          Chicama      PE  -7.8447  -79.1469    296.36        66
# 710  Port Hawkesbury      CA  45.6169  -61.3485    274.15        69
# 711             Soyo      AO  -6.1349   12.3689    299.63        85
# 712        Kavaratti      IN  10.5669   72.6420    300.49        61
#
#      Cloudiness  Wind Speed Current Description
# 0            40        4.12    scattered clouds
# 1            73        0.51       broken clouds
# 2            10        2.06           clear sky
# 3            40        2.06    scattered clouds
# 4            90        2.06     overcast clouds
# ..          ...         ...                 ...
# 708           0        7.72           clear sky
# 709         100        3.58     overcast clouds
# 710          90        7.20     overcast clouds
# 711         100        3.70     overcast clouds
# 712          43        4.52    scattered clouds
#
# [713 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
